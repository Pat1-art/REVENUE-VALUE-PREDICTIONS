# %%
# I first imported the relevant libraries in python that I'll use in my analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import dates
# %matplotlib inline
import statsmodels.api as sm
import seaborn as sns

# %%
#I then imported the data to be used in our analysis.
#I indexed our data by virtue of month and converted the months into dates which can be recognised by machine language.

revenue=pd.read_excel('frank data.xls',index_col='MONTH',parse_dates=True)
revenue=revenue.asfreq('MS')
revenue.head()
# Out:
#             NO.OF EMPLOYERS 2019/2020  No.of CO 2019/20  No.of Audits 2019/20  \
# MONTH
# 2020-07-01                     2842.0              29.0                 238.0
# 2020-08-01                     2982.0              24.0                 165.0
# 2020-09-01                     3016.0              24.0                 200.0
# 2020-10-01                     3150.0              34.0                 360.0
# 2020-11-01                     3035.0              39.0                 229.0
#
#              REVENUE2019/2020  TOTAL DEBT 2019/2020  \
# MONTH
# 2020-07-01       4.600654e+08           145698018.0
# 2020-08-01       1.422498e+09           159532321.0
# 2020-09-01       7.267268e+08           169228894.0
# 2020-10-01       1.406029e+09           180885997.0
# 2020-11-01       8.588977e+08           157679690.0
#
#             NO.OF EMPLOYERS 2020/2021  No.of CO 2020/21  No.of Audits 2020/21  \
# MONTH
# 2020-07-01                     4226.0               0.0                   0.0
# 2020-08-01                     4183.0               2.0                   2.0
# 2020-09-01                     4257.0               3.0                   3.0
# 2020-10-01                     4336.0               6.0                   6.0
# 2020-11-01                     4269.0               4.0                   4.0
#
#               REVENUE2020/2021  TOTAL DEBT 2020/2021  No. of New Employers
# MONTH
# 2020-07-01        3.244203e+08           271121229.0                 165.0
# 2020-08-01        1.446884e+09           290219607.0                 140.0
# 2020-09-01        9.821314e+08           324771455.0                 171.0
# 2020-10-01        1.127531e+09           324739953.0                 310.0
# 2020-11-01        1.068581e+09           332889551.0                 349.0

# %%
revenue.describe()
# The above gives us the basic infomation of our data such as mean,minimum value ,maximum value,our quartiles,
#the standard deviation from the mean and the number of values in our data(count)

#i.e the mean debt in the year 2019/2020 is 175.3 million
# Out:
#        NO.OF EMPLOYERS 2019/2020  No.of CO 2019/20  No.of Audits 2019/20  \
# count                  10.000000         10.000000             10.000000
# mean                 3182.100000         24.100000            166.400000
# std                   292.270214         11.415876            109.871845
# min                  2842.000000          2.000000              2.000000
# 25%                  3020.750000         23.250000             88.500000
# 50%                  3114.500000         24.500000            182.500000
# 75%                  3263.250000         32.000000            230.500000
# max                  3889.000000         39.000000            360.000000
#
#         REVENUE2019/2020  TOTAL DEBT 2019/2020  NO.OF EMPLOYERS 2020/2021  \
# count       1.000000e+01          1.000000e+01                  10.000000
# mean        9.554294e+08          1.753036e+08                4235.300000
# std         4.707167e+08          1.957765e+07                 179.814132
# min         3.398154e+08          1.456980e+08                3821.000000
# 25%         5.267307e+08          1.619565e+08                4193.750000
# 50%         9.057893e+08          1.755137e+08                4263.000000
# 75%         1.365327e+09          1.839208e+08                4324.750000
# max         1.695435e+09          2.156331e+08                4489.000000
#
#        No.of CO 2020/21  No.of Audits 2020/21    REVENUE2020/2021  \
# count         10.000000             10.000000        1.000000e+01
# mean           3.400000              3.500000        1.014750e+09
# std            2.221111              2.321398        3.719490e+08
# min            0.000000              0.000000        3.244203e+08
# 25%            2.000000              2.000000        9.067304e+08
# 50%            3.500000              3.500000        1.098056e+09
# 75%            4.750000              5.500000        1.170790e+09
# max            7.000000              7.000000        1.495650e+09
#
#        TOTAL DEBT 2020/2021  No. of New Employers
# count          1.000000e+01             10.000000
# mean           2.857845e+08            592.500000
# std            6.632966e+07            547.340895
# min            1.645965e+08            140.000000
# 25%            2.758958e+08            170.250000
# 50%            3.188808e+08            329.500000
# 75%            3.273408e+08            819.250000
# max            3.403877e+08           1616.000000

# %%
# I then proceded to find the coefficient of correlation to find out what parameters influence each other the most
revenue.corr()
#We can clearly see that Revenue fro each financial year affect each other the most,having a correlation coefficient of 0.733033
# Out:
#                            NO.OF EMPLOYERS 2019/2020  No.of CO 2019/20  \
# NO.OF EMPLOYERS 2019/2020                   1.000000         -0.728940
# No.of CO 2019/20                           -0.728940          1.000000
# No.of Audits 2019/20                       -0.606876          0.865266
#  REVENUE2019/2020                          -0.200975         -0.053025
# TOTAL DEBT 2019/2020                        0.940403         -0.673096
# NO.OF EMPLOYERS 2020/2021                  -0.639396          0.814669
# No.of CO 2020/21                            0.140112          0.331284
# No.of Audits 2020/21                        0.117993          0.320745
#   REVENUE2020/2021                          0.304089         -0.464757
# TOTAL DEBT 2020/2021                       -0.675614          0.892413
# No. of New Employers                        0.226187         -0.148990
#
#                            No.of Audits 2019/20   REVENUE2019/2020  \
# NO.OF EMPLOYERS 2019/2020             -0.606876          -0.200975
# No.of CO 2019/20                       0.865266          -0.053025
# No.of Audits 2019/20                   1.000000          -0.056813
#  REVENUE2019/2020                     -0.056813           1.000000
# TOTAL DEBT 2019/2020                  -0.506254          -0.104694
# NO.OF EMPLOYERS 2020/2021              0.653871           0.081869
# No.of CO 2020/21                       0.391288           0.108699
# No.of Audits 2020/21                   0.364625           0.103723
#   REVENUE2020/2021                    -0.446938           0.733033
# TOTAL DEBT 2020/2021                   0.720969          -0.068114
# No. of New Employers                  -0.302574           0.286860
#
#                            TOTAL DEBT 2019/2020  NO.OF EMPLOYERS 2020/2021  \
# NO.OF EMPLOYERS 2019/2020              0.940403                  -0.639396
# No.of CO 2019/20                      -0.673096                   0.814669
# No.of Audits 2019/20                  -0.506254                   0.653871
#  REVENUE2019/2020                     -0.104694                   0.081869
# TOTAL DEBT 2019/2020                   1.000000                  -0.457930
# NO.OF EMPLOYERS 2020/2021             -0.457930                   1.000000
# No.of CO 2020/21                       0.348789                   0.524637
# No.of Audits 2020/21                   0.348027                   0.539691
#   REVENUE2020/2021                     0.303148                  -0.462028
# TOTAL DEBT 2020/2021                  -0.536418                   0.869427
# No. of New Employers                   0.297634                   0.301342
#
#                            No.of CO 2020/21  No.of Audits 2020/21  \
# NO.OF EMPLOYERS 2019/2020          0.140112              0.117993
# No.of CO 2019/20                   0.331284              0.320745
# No.of Audits 2019/20               0.391288              0.364625
#  REVENUE2019/2020                  0.108699              0.103723
# TOTAL DEBT 2019/2020               0.348789              0.348027
# NO.OF EMPLOYERS 2020/2021          0.524637              0.539691
# No.of CO 2020/21                   1.000000              0.991278
# No.of Audits 2020/21               0.991278              1.000000
#   REVENUE2020/2021                -0.036329             -0.051895
# TOTAL DEBT 2020/2021               0.343603              0.359364
# No. of New Employers               0.473616              0.466229
#
#                              REVENUE2020/2021  TOTAL DEBT 2020/2021  \
# NO.OF EMPLOYERS 2019/2020            0.304089             -0.675614
# No.of CO 2019/20                    -0.464757              0.892413
# No.of Audits 2019/20                -0.446938              0.720969
#  REVENUE2019/2020                    0.733033             -0.068114
# TOTAL DEBT 2019/2020                 0.303148             -0.536418
# NO.OF EMPLOYERS 2020/2021           -0.462028              0.869427
# No.of CO 2020/21                    -0.036329              0.343603
# No.of Audits 2020/21                -0.051895              0.359364
#   REVENUE2020/2021                   1.000000             -0.401873
# TOTAL DEBT 2020/2021                -0.401873              1.000000
# No. of New Employers                 0.041438             -0.140357
#
#                            No. of New Employers
# NO.OF EMPLOYERS 2019/2020              0.226187
# No.of CO 2019/20                      -0.148990
# No.of Audits 2019/20                  -0.302574
#  REVENUE2019/2020                      0.286860
# TOTAL DEBT 2019/2020                   0.297634
# NO.OF EMPLOYERS 2020/2021              0.301342
# No.of CO 2020/21                       0.473616
# No.of Audits 2020/21                   0.466229
#   REVENUE2020/2021                     0.041438
# TOTAL DEBT 2020/2021                  -0.140357
# No. of New Employers                   1.000000

# %%
#Graph plotting(revenue Data 2019/2020 and 2020/2021)

# %%
fig=plt.figure(figsize=(12,6))
ax=fig.add_axes([0.0,0.0,0.9,0.9])
ax.set_xlabel('Month')
ax.set_ylabel('revenue')
ax.set_title('revenue over time in hundreds of millions')
ax.plot(revenue.index,revenue['  REVENUE2020/2021'],label='Revenue(2020/2021)')
plt.plot(revenue.index,revenue[' REVENUE2019/2020'],label='Revenue(2019/2020)')
plt.legend(loc=0)
plt.grid(True,color='0.6',dashes=(5,1,2,1))

# %%
# FORECASTING THE REVENUE

# %%
# The data is Time Series Data.
#A Time series may contain either,a trend,seasonality or noise(random).
# Our Data has no Seasonality and since noise in time series cannot be used in forecasting,we will use the trend component.
#We shall use the holt winter model that accounts for trend but no seasonality.

# %%
# We begin by importing our libraries
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
# We split our data into two
train_df=revenue.iloc[:7]
test_df=revenue.iloc[6:]

# %%
# We now fit our training data to our model.
model_fit=ExponentialSmoothing(train_df['  REVENUE2020/2021'],trend='add',seasonal='add',seasonal_periods=6,freq='MS').fit()
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
predictions=model_fit.forecast(7)

# %%
predictions # in hundreds of millions
# Out:
# 2021-02-01    1.911269e+09
# 2021-03-01    1.602155e+09
# 2021-04-01    1.901855e+09
# 2021-05-01    1.997731e+09
# 2021-06-01    2.234111e+09
# 2021-07-01    1.578444e+09
# 2021-08-01    2.861066e+09
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(30,10))

plt.plot(train_df['  REVENUE2020/2021'],label=' Training Total revenue(2020/2021)')
plt.plot(test_df[' REVENUE2019/2020'],label='Testing Total Revenue(2020/2021)')
plt.plot(predictions,label='Predicted Total Revenue(2020/2021)')
plt.legend(loc=0)
plt.grid(True,color='0.6',dashes=(5,1,2,1))

# %%
#Explanation

# %%
#There was a sudden and significant Drop in in Debt in the period of 2021-02 and 2021-04.
#This can be attributed to the third wave of covid-19 and the lockdown imposed and various external factors.
#Also,This period is also too brief and carries little weight in our predictions.
